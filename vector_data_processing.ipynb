# %% [markdown]
# <a href="https://colab.research.google.com/github/biko3036/gxp/blob/master/vector_data_processing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install geopandas
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 1.0 MB 5.1 MB/s
# ...
#      |████████████████████████████████| 6.3 MB 42.3 MB/s
# ...
#      |████████████████████████████████| 16.7 MB 470 kB/s
# ...

# %%
import geopandas as gpd

# %%
in_geojson = r'/content/drive/MyDrive/Colab Notebooks/Vector data processing/data/municipality.json'
in_shp = r'/content/drive/MyDrive/Colab Notebooks/Vector data processing/data/municipality.shp'

# %%
gdf = gpd.read_file(in_geojson)

# %%
gdf.head()
# Out:
#    OBJECTID   DISTRICT        GaPa_NaPa     Type_GN Province  SCode  DCode  \
# 0         1  TAPLEJUNG  Aathrai Tribeni  Gaunpalika        1      1      1
# 1         2  TAPLEJUNG       Maiwakhola  Gaunpalika        1      1      1
# 2         3  TAPLEJUNG        Meringden  Gaunpalika        1      1      1
# 3         4  TAPLEJUNG       Mikwakhola  Gaunpalika        1      1      1
# 4         5  TAPLEJUNG     Phaktanglung  Gaunpalika        1      1      1
#
#    SDD  MCode      length         area  SDDMM          Nepali  Shape_Leng  \
# 0  101      1   44.672747    88.825948  10101  आठराई त्रिवेणी    0.430900
# 1  101      2   61.067429   137.848122  10102        मैवाखोला    0.577692
# 2  101      3   75.987469   210.313039  10103        मेरिङदेन    0.718499
# 3  101      4  123.175400   442.960328  10104      मिक्वाखोला    1.164097
# 4  101      5  228.107830  1858.441119  10105       फक्ताङलुङ    2.186142
#
#    Shape_Area                                           geometry
# ...

# %%
gdf = gpd.read_file(in_shp)

# %%
gdf.head()
# Out:
#    OBJECTID   DISTRICT        GaPa_NaPa     Type_GN Province  SCode  DCode  \
# 0         1  TAPLEJUNG  Aathrai Tribeni  Gaunpalika        1      1      1
# 1         2  TAPLEJUNG       Maiwakhola  Gaunpalika        1      1      1
# 2         3  TAPLEJUNG        Meringden  Gaunpalika        1      1      1
# 3         4  TAPLEJUNG       Mikwakhola  Gaunpalika        1      1      1
# 4         5  TAPLEJUNG     Phaktanglung  Gaunpalika        1      1      1
#
#    SDD  MCode      length         area  SDDMM  \
# 0  101      1   44.672747    88.825948  10101
# 1  101      2   61.067429   137.848122  10102
# 2  101      3   75.987469   210.313039  10103
# 3  101      4  123.175400   442.960328  10104
# 4  101      5  228.107830  1858.441119  10105
#
#                                      Nepali  Shape_Leng  Shape_Area  \
# 0  à¤à¤ à¤°à¤¾à¤ à¤¤à¥à¤°à¤¿à¤µà¥à¤£à¥    0.430900    0.008075
# 1                  à¤®à¥à¤µà¤¾à¤à¥à¤²à¤¾    0.577692    0.012540
# ...

# %%
gdf.crs
# Out:
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: World.
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984 ensemble
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
gdf.geom_type
# Out:
# 0      Polygon
# 1      Polygon
# 2      Polygon
# 3      Polygon
# 4      Polygon
#         ...
# 769    Polygon
# 770    Polygon
# 771    Polygon
# 772    Polygon
# 773    Polygon
# Length: 774, dtype: object

# %%
gdf.plot()

# %%
gdf.plot('DISTRICT')

# %%
gdf.plot('Province', legend=True)

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots(1, figsize=(4.5, 10))
gdf.plot(ax=ax, column='Province', legend=True, legend_kwds={"loc": 'center left'})
leg = ax.get_legend()
leg.set_bbox_to_anchor((1.04, 0.5))

# %%
gdf.to_file(r'/content/drive/MyDrive/Colab Notebooks/Vector data processing/Output/out_shp.shp')

# %%
gdf.to_file(r'/content/drive/MyDrive/Colab Notebooks/Vector data processing/Output/out_geojson.geojson', driver='GeoJSON', encoding="utf-8")

# %%
gdf.to_file(r'/content/drive/MyDrive/Colab Notebooks/Vector data processing/Output/out_geopackage.gpkg', layer="m", driver='GPKG', encoding="utf-8")

# %%
gdf['Province'] == '1'
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#        ...
# 769    False
# 770    False
# 771    False
# 772    False
# 773    False
# Name: Province, Length: 774, dtype: bool

# %%
prov_1 = gdf[gdf['Province'] == '1']
len(prov_1)
# Out:
# 139

# %%
prov_1.plot('DISTRICT')

# %%
dist = gdf[gdf['DISTRICT'] == 'TAPLEJUNG']
dist.head()
# Out:
#    OBJECTID   DISTRICT        GaPa_NaPa     Type_GN Province  SCode  DCode  \
# 0         1  TAPLEJUNG  Aathrai Tribeni  Gaunpalika        1      1      1
# 1         2  TAPLEJUNG       Maiwakhola  Gaunpalika        1      1      1
# 2         3  TAPLEJUNG        Meringden  Gaunpalika        1      1      1
# 3         4  TAPLEJUNG       Mikwakhola  Gaunpalika        1      1      1
# 4         5  TAPLEJUNG     Phaktanglung  Gaunpalika        1      1      1
#
#    SDD  MCode      length         area  SDDMM  \
# 0  101      1   44.672747    88.825948  10101
# 1  101      2   61.067429   137.848122  10102
# 2  101      3   75.987469   210.313039  10103
# 3  101      4  123.175400   442.960328  10104
# 4  101      5  228.107830  1858.441119  10105
#
#                                      Nepali  Shape_Leng  Shape_Area  \
# 0  à¤à¤ à¤°à¤¾à¤ à¤¤à¥à¤°à¤¿à¤µà¥à¤£à¥    0.430900    0.008075
# 1                  à¤®à¥à¤µà¤¾à¤à¥à¤²à¤¾    0.577692    0.012540
# ...

# %%
dist.plot()

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(16.53, 11.69))
gdf.plot(ax=ax1, column="Province")
prov_1.plot(ax=ax2, column="DISTRICT")

# %%
gdf['Area']=0
gdf.head()
# Out:
#    OBJECTID   DISTRICT        GaPa_NaPa     Type_GN Province  SCode  DCode  \
# 0         1  TAPLEJUNG  Aathrai Tribeni  Gaunpalika        1      1      1
# 1         2  TAPLEJUNG       Maiwakhola  Gaunpalika        1      1      1
# 2         3  TAPLEJUNG        Meringden  Gaunpalika        1      1      1
# 3         4  TAPLEJUNG       Mikwakhola  Gaunpalika        1      1      1
# 4         5  TAPLEJUNG     Phaktanglung  Gaunpalika        1      1      1
#
#    SDD  MCode      length         area  SDDMM  \
# 0  101      1   44.672747    88.825948  10101
# 1  101      2   61.067429   137.848122  10102
# 2  101      3   75.987469   210.313039  10103
# 3  101      4  123.175400   442.960328  10104
# 4  101      5  228.107830  1858.441119  10105
#
#                                      Nepali  Shape_Leng  Shape_Area  \
# 0  à¤à¤ à¤°à¤¾à¤ à¤¤à¥à¤°à¤¿à¤µà¥à¤£à¥    0.430900    0.008075
# 1                  à¤®à¥à¤µà¤¾à¤à¥à¤²à¤¾    0.577692    0.012540
# ...

# %%
gdf_copy = gdf.copy
gdf_copy = gdf.to_crs(epsg=32645)
gdf_copy['Area'] = gdf_copy.geometry.area/10**6

# %%
gdf_copy.head()
# Out:
#    OBJECTID   DISTRICT        GaPa_NaPa     Type_GN Province  SCode  DCode  \
# 0         1  TAPLEJUNG  Aathrai Tribeni  Gaunpalika        1      1      1
# 1         2  TAPLEJUNG       Maiwakhola  Gaunpalika        1      1      1
# 2         3  TAPLEJUNG        Meringden  Gaunpalika        1      1      1
# 3         4  TAPLEJUNG       Mikwakhola  Gaunpalika        1      1      1
# 4         5  TAPLEJUNG     Phaktanglung  Gaunpalika        1      1      1
#
#    SDD  MCode      length         area  SDDMM  \
# 0  101      1   44.672747    88.825948  10101
# 1  101      2   61.067429   137.848122  10102
# 2  101      3   75.987469   210.313039  10103
# 3  101      4  123.175400   442.960328  10104
# 4  101      5  228.107830  1858.441119  10105
#
#                                      Nepali  Shape_Leng  Shape_Area  \
# 0  à¤à¤ à¤°à¤¾à¤ à¤¤à¥à¤°à¤¿à¤µà¥à¤£à¥    0.430900    0.008075
# 1                  à¤®à¥à¤µà¤¾à¤à¥à¤²à¤¾    0.577692    0.012540
# ...

# %%
gdf_copy.plot('Area')

# %%
gdf_area_filter = gdf_copy[gdf_copy['Area'] > 200]

# %%
gdf_area_filter.plot(column='Area', legend=True)

# %%
prov_1.to_file(r'/content/drive/MyDrive/Colab Notebooks/Vector data processing/Output/prov_1.shp')

# %%
gdf_copy.to_file(r'/content/drive/MyDrive/Colab Notebooks/Vector data processing/Output/gdf_copy.shp')
# Out:
# WARNING:fiona._env:Normalized/laundered field name: 'Area' to 'Area_1'

# %%
gdf_copy.to_file(r'/content/drive/MyDrive/Colab Notebooks/Vector data processing/Output/gdf_copy.geojson', driver='GeoJSON', encoding="utf-8")

# %%
gdf_area_filter.to_file(r'/content/drive/MyDrive/Colab Notebooks/Vector data processing/Output/gdf_area_filter.shp')
# Out:
# WARNING:fiona._env:Normalized/laundered field name: 'Area' to 'Area_1'

# %%
gdf_area_filter.to_file(r'/content/drive/MyDrive/Colab Notebooks/Vector data processing/Output/gdf_area_filter.geojson', driver='GeoJSON', encoding="utf-8")

# %%
gdf_copy.head(2)
# Out:
#    OBJECTID   DISTRICT        GaPa_NaPa     Type_GN Province  SCode  DCode  \
# 0         1  TAPLEJUNG  Aathrai Tribeni  Gaunpalika        1      1      1
# 1         2  TAPLEJUNG       Maiwakhola  Gaunpalika        1      1      1
#
#    SDD  MCode     length        area  SDDMM  \
# 0  101      1  44.672747   88.825948  10101
# 1  101      2  61.067429  137.848122  10102
#
#                                      Nepali  Shape_Leng  Shape_Area  \
# 0  à¤à¤ à¤°à¤¾à¤ à¤¤à¥à¤°à¤¿à¤µà¥à¤£à¥    0.430900    0.008075
# 1                  à¤®à¥à¤µà¤¾à¤à¥à¤²à¤¾    0.577692    0.012540
#
#                                             geometry        Area
# 0  POLYGON ((560043.031 3027645.815, 560164.182 3...   88.500797
# 1  POLYGON ((549552.740 3034086.675, 549819.850 3...  137.365137

# %%
gdf_filter = gdf_copy[['DISTRICT', 'Area', 'geometry']]
gdf.head()
# Out:
#    OBJECTID   DISTRICT        GaPa_NaPa     Type_GN Province  SCode  DCode  \
# 0         1  TAPLEJUNG  Aathrai Tribeni  Gaunpalika        1      1      1
# 1         2  TAPLEJUNG       Maiwakhola  Gaunpalika        1      1      1
# 2         3  TAPLEJUNG        Meringden  Gaunpalika        1      1      1
# 3         4  TAPLEJUNG       Mikwakhola  Gaunpalika        1      1      1
# 4         5  TAPLEJUNG     Phaktanglung  Gaunpalika        1      1      1
#
#    SDD  MCode      length         area  SDDMM  \
# 0  101      1   44.672747    88.825948  10101
# 1  101      2   61.067429   137.848122  10102
# 2  101      3   75.987469   210.313039  10103
# 3  101      4  123.175400   442.960328  10104
# 4  101      5  228.107830  1858.441119  10105
#
#                                      Nepali  Shape_Leng  Shape_Area  \
# 0  à¤à¤ à¤°à¤¾à¤ à¤¤à¥à¤°à¤¿à¤µà¥à¤£à¥    0.430900    0.008075
# 1                  à¤®à¥à¤µà¤¾à¤à¥à¤²à¤¾    0.577692    0.012540
# ...

# %%
gdf_district = gdf_filter.dissolve(by= 'DISTRICT', aggfunc='sum')
gdf_district.head()
# Out:
#                                                        geometry         Area
# DISTRICT
# ACHHAM        POLYGON ((-56423.948 3213010.677, -56653.749 3...  1711.693907
# ARGHAKHANCHI  POLYGON ((106619.981 3096066.561, 106685.990 3...  1242.713215
# BAGLUNG       POLYGON ((134739.767 3123827.977, 134575.752 3...  1840.560401
# BAITADI       POLYGON ((-144618.018 3264503.806, -144754.203...  1505.749216
# BAJHANG       POLYGON ((-60647.761 3267497.297, -60874.410 3...  3483.090774

# %%
gdf_district.plot('Area', cmap="RdYlGn_r", legend=True)

# %%
gdf_district.to_file(r'/content/drive/MyDrive/Colab Notebooks/Vector data processing/Output/gdf_district.shp')

# %%
gdf_district.to_file(r'/content/drive/MyDrive/Colab Notebooks/Vector data processing/Output/gdf_district.geojson', driver='GeoJSON', encoding='utf-8')

# %%
gdf = gpd.read_file(r'/content/drive/MyDrive/Colab Notebooks/Vector data processing/Output/gdf_district.shp')
gdf.head()
# Out:
#        DISTRICT         Area  \
# 0        ACHHAM  1711.693907
# 1  ARGHAKHANCHI  1242.713215
# 2       BAGLUNG  1840.560401
# 3       BAITADI  1505.749216
# 4       BAJHANG  3483.090774
#
#                                             geometry
# 0  POLYGON ((-56423.948 3213010.677, -56653.749 3...
# 1  POLYGON ((106619.981 3096066.561, 106685.990 3...
# 2  POLYGON ((134739.767 3123827.977, 134575.752 3...
# 3  POLYGON ((-144618.018 3264503.806, -144754.203...
# 4  POLYGON ((-60647.761 3267497.297, -60874.410 3...

# %%
import pandas as pd

df_population = pd.read_csv(r'/content/drive/MyDrive/Colab Notebooks/Vector data processing/data/015 population.csv')
df_population.head()
# Out:
#        District  registered voters  Total population  Unnamed: 3    DIST UPPER
# 0        Achham             257477            127742         NaN        ACHHAM
# 1  Arghakhanchi             197632            126699         NaN  ARGHAKHANCHI
# 2       Baglung             268613            156802         NaN       BAGLUNG
# 3       Baitadi             250898            124824         NaN       BAITADI
# 4       Bajhang             195159             97610         NaN       BAJHANG

# %%
gdf_population = gdf.merge(df_population, how="left", left_on="DISTRICT", right_on="DIST UPPER")
gdf_population.head()
# Out:
#        DISTRICT         Area  \
# 0        ACHHAM  1711.693907
# 1  ARGHAKHANCHI  1242.713215
# 2       BAGLUNG  1840.560401
# 3       BAITADI  1505.749216
# 4       BAJHANG  3483.090774
#
#                                             geometry      District  \
# 0  POLYGON ((-56423.948 3213010.677, -56653.749 3...        Achham
# 1  POLYGON ((106619.981 3096066.561, 106685.990 3...  Arghakhanchi
# 2  POLYGON ((134739.767 3123827.977, 134575.752 3...       Baglung
# 3  POLYGON ((-144618.018 3264503.806, -144754.203...       Baitadi
# 4  POLYGON ((-60647.761 3267497.297, -60874.410 3...       Bajhang
#
#    registered voters  Total population  Unnamed: 3    DIST UPPER
# 0           257477.0          127742.0         NaN        ACHHAM
# 1           197632.0          126699.0         NaN  ARGHAKHANCHI
# 2           268613.0          156802.0         NaN       BAGLUNG
# 3           250898.0          124824.0         NaN       BAITADI
# ...

# %%
gdf_population = gdf_population[['DISTRICT', 'Area', 'geometry', 'Total population']]

# %%
gdf_population.head()
# Out:
#        DISTRICT         Area  \
# 0        ACHHAM  1711.693907
# 1  ARGHAKHANCHI  1242.713215
# 2       BAGLUNG  1840.560401
# 3       BAITADI  1505.749216
# 4       BAJHANG  3483.090774
#
#                                             geometry  Total population
# 0  POLYGON ((-56423.948 3213010.677, -56653.749 3...          127742.0
# 1  POLYGON ((106619.981 3096066.561, 106685.990 3...          126699.0
# 2  POLYGON ((134739.767 3123827.977, 134575.752 3...          156802.0
# 3  POLYGON ((-144618.018 3264503.806, -144754.203...          124824.0
# 4  POLYGON ((-60647.761 3267497.297, -60874.410 3...           97610.0

# %%
gdf_population.to_file(r'/content/drive/MyDrive/Colab Notebooks/Vector data processing/Output/gdf_population.shp')
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
#   """Entry point for launching an IPython kernel.
# WARNING:fiona._env:Normalized/laundered field name: 'Total population' to 'Total popu'

# %%
gdf_population.to_file(r'/content/drive/MyDrive/Colab Notebooks/Vector data processing/Output/gdf_population.geojson', driver='GeoJSON', encoding='utf-8')

# %%
null_val = gdf_population[gdf_population['Total population'].isnull()]
null_val
# Out:
#          DISTRICT         Area  \
# 46  NAWALPARASI_E  1428.013639
# 47  NAWALPARASI_W   727.499742
# 59        RUKUM_E  1687.685423
# 60        RUKUM_W  1217.955336
#
#                                              geometry  Total population
# 46  POLYGON ((197076.324 3040128.155, 196864.196 3...               NaN
# 47  POLYGON ((192306.170 3046641.350, 192459.395 3...               NaN
# 59  POLYGON ((106262.929 3173061.569, 106242.470 3...               NaN
# 60  POLYGON ((58816.596 3166737.287, 58756.611 316...               NaN

# %%
len(null_val)
# Out:
# 4

# %%
gdf_population.plot('Total population', legend=True)
